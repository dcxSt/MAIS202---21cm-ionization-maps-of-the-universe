# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os

# %%
def filenames_in(mypath="../joelle_batch_2.1/joelle_ESC_FRAC_0.070_RNG_150/"):
    filesnames = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath,f))]
    return filenames

# %%
def binary_to_3dbox(file):
    f_21cm = open(file,"rb")
    binary_21cm = f_21cm.read()
    np_float_array_21cm = np.fromstring(binary_21cm, np.float32)
    f_21cm.close()
    
    # return one slice
    return np.reshape(np_float_array_21cm, (200,200,200))

# %%
def save_one_slice(filename):
    # saves one slice of 3d box
    #filename = input()
    box = binary_to_3dbox(filename)
    return box
    #np.savetxt(filename + '.txt',box[:,0], delimiter=',')

# %%
def read_binary(fname):
    f21 = open(fname , "rb")
    binary21 = f21.read()
    np_float_array21 = np.fromstring(binary21, np.float32)
    f21.close()
    return np_float_array21

# %%
binf21= read_binary("../joelle_batch_2.1/joelle_ESC_FRAC_0.070_RNG_150/delta_T_v3_z005.00_nf0.000000_useTs0_200_300Mpc")
# Out:
# /home/steve/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   after removing the cwd from sys.path.

# %%
bin21slice = save_one_slice("../joelle_batch_2.1/joelle_ESC_FRAC_0.070_RNG_150/delta_T_v3_z005.50_nf0.041347_useTs0_200_300Mpc")
# Out:
# /home/steve/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   after removing the cwd from sys.path.

# %%
i = bin21slice[5]

# %%
bin21slice.shape
# Out:
# (200, 200, 200)

# %%
# pick a random slice and display it
rand_slice = random.choice(bin21slice)

# %%
rand_slice.shape
# Out:
# (200, 200)

# %%
# random slices
plt.figure(figsize=(14,7))
for i in range(3*2):
        plt.subplot(2,3,i+1)
        plt.imshow(random.choice(bin21slice),cmap=cm.plasma)

plt.show()

# %%
#
